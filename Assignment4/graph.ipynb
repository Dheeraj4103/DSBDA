# %%
# import pandas library
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
# Reading csv file
data = pd.read_csv("Heart.csv")
# creating a dataframe of it
data = pd.DataFrame(data)
data.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
val = data['ChestPain'].value_counts()
print(val)
labels = ['Typical', 'asymptomatic', 'Nontypical', 'Nonanginal']
x = [23, 144, 50, 86]
plt.pie(x, labels=labels, autopct='%1.1f%%')
# Out:
# asymptomatic    144
# nonanginal       86
# nontypical       50
# typical          23
# Name: ChestPain, dtype: int64
# ([<matplotlib.patches.Wedge at 0x20ccbbf34f0>,
#   <matplotlib.patches.Wedge at 0x20ccbbf3a60>,
#   <matplotlib.patches.Wedge at 0x20ccbc3c130>,
#   <matplotlib.patches.Wedge at 0x20ccbc3c7c0>],
#  [Text(1.0688703878101182, 0.25983859232732825, 'Typical'),
#   Text(-0.4275284961750052, 1.0135183199914735, 'asymptomatic'),
#   Text(-0.7343469291842987, -0.8189838750534658, 'Nontypical'),
#   Text(0.6909220905824778, -0.8559361335667157, 'Nonanginal')],
#  [Text(0.5830202115327917, 0.14173014126945177, '7.6%'),
#   Text(-0.2331973615500028, 0.5528281745408037, '47.5%'),
#   Text(-0.4005528704641629, -0.4467184773018904, '16.5%'),
#   Text(0.3768665948631697, -0.46687425467275395, '28.4%')])

# %%
val = data['Thal'].value_counts()
print(val)
labels = ['Fixed', 'Normal', 'Reversable']
x = [166, 117, 18]
plt.pie(x, labels=labels, autopct='%1.1f%%')
# Out:
# normal        166
# reversable    117
# fixed          18
# Name: Thal, dtype: int64
# ([<matplotlib.patches.Wedge at 0x20ccde48040>,
#   <matplotlib.patches.Wedge at 0x20ccde48670>,
#   <matplotlib.patches.Wedge at 0x20ccde48d00>],
#  [Text(-0.17717879093667105, 1.0856369909146517, 'Fixed'),
#   Text(-0.02869897117848817, -1.0996255585667771, 'Normal'),
#   Text(1.0806448558683255, -0.2054426817516895, 'Reversable')],
#  [Text(-0.09664297687454783, 0.5921656314079917, '55.1%'),
#   Text(-0.015653984279175363, -0.599795759218242, '38.9%'),
#   Text(0.5894426486554503, -0.11205964459183064, '6.0%')])

# %%
val = data['AHD'].value_counts()
print(val)
labels = ['No', 'Yes']
x = [164, 139]
plt.pie(x, labels=labels, autopct='%1.1f%%')
# Out:
# No     164
# Yes    139
# Name: AHD, dtype: int64
# ([<matplotlib.patches.Wedge at 0x20ccde7f790>,
#   <matplotlib.patches.Wedge at 0x20ccde7fe20>],
#  [Text(-0.14216517139859375, 1.0907745248405871, 'No'),
#   Text(0.1421650692729111, -1.0907745381510465, 'Yes')],
#  [Text(-0.07754463894468748, 0.5949679226403202, '54.1%'),
#   Text(0.07754458323976968, -0.5949679299005707, '45.9%')])

# %%
sns.set_theme(style="ticks")
sns.pairplot(data, hue="AHD", diag_kind="hist", height=1.5)

# %%
sns.histplot(data=data,x=data['Age'], hue='AHD')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=data,x=data['Sex'], hue='AHD')
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='Count'>

# %%
sns.histplot(data=data,x=data['ChestPain'], hue='AHD')
# Out:
# <AxesSubplot: xlabel='ChestPain', ylabel='Count'>

# %%
sns.histplot(data=data,x=data['RestBP'], hue='AHD')
# Out:
# <AxesSubplot: xlabel='RestBP', ylabel='Count'>

# %%
sns.countplot(data=data, x=data['Sex'])
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(data=data, x=data['ChestPain'])
# Out:
# <AxesSubplot: xlabel='ChestPain', ylabel='count'>

# %%
sns.countplot(data=data, x=data['RestECG'])
# Out:
# <AxesSubplot: xlabel='RestECG', ylabel='count'>

# %%
sns.countplot(data=data, x=data['ExAng'])
# Out:
# <AxesSubplot: xlabel='ExAng', ylabel='count'>

# %%
sns.scatterplot(data=data, x="Age", y="RestBP", hue="AHD")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='RestBP'>

# %%
sns.scatterplot(data=data, x="Age", y="Chol", hue="AHD")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Chol'>

# %%
sns.scatterplot(data=data, x="RestBP", y="MaxHR", hue="AHD")
# Out:
# <AxesSubplot: xlabel='RestBP', ylabel='MaxHR'>

# %%
sns.scatterplot(data=data, x="MaxHR", y="Age", hue="AHD")
# Out:
# <AxesSubplot: xlabel='MaxHR', ylabel='Age'>

# %%
sns.scatterplot(data=data, x="Chol", y="Oldpeak", hue="AHD")
# Out:
# <AxesSubplot: xlabel='Chol', ylabel='Oldpeak'>

# %%
sns.scatterplot(data=data, x="Oldpeak", y="RestBP", hue="AHD")
# Out:
# <AxesSubplot: xlabel='Oldpeak', ylabel='RestBP'>

# %%
pd.plotting.scatter_matrix(data, figsize=(10, 10))
# Out:
# array([[<AxesSubplot: xlabel='Unnamed: 0', ylabel='Unnamed: 0'>,
#         <AxesSubplot: xlabel='Age', ylabel='Unnamed: 0'>,
#         <AxesSubplot: xlabel='Sex', ylabel='Unnamed: 0'>,
#         <AxesSubplot: xlabel='RestBP', ylabel='Unnamed: 0'>,
#         <AxesSubplot: xlabel='Chol', ylabel='Unnamed: 0'>,
#         <AxesSubplot: xlabel='Fbs', ylabel='Unnamed: 0'>,
#         <AxesSubplot: xlabel='RestECG', ylabel='Unnamed: 0'>,
#         <AxesSubplot: xlabel='MaxHR', ylabel='Unnamed: 0'>,
#         <AxesSubplot: xlabel='ExAng', ylabel='Unnamed: 0'>,
#         <AxesSubplot: xlabel='Oldpeak', ylabel='Unnamed: 0'>,
#         <AxesSubplot: xlabel='Slope', ylabel='Unnamed: 0'>,
#         <AxesSubplot: xlabel='Ca', ylabel='Unnamed: 0'>],
#        [<AxesSubplot: xlabel='Unnamed: 0', ylabel='Age'>,
#         <AxesSubplot: xlabel='Age', ylabel='Age'>,
#         <AxesSubplot: xlabel='Sex', ylabel='Age'>,
#         <AxesSubplot: xlabel='RestBP', ylabel='Age'>,
#         <AxesSubplot: xlabel='Chol', ylabel='Age'>,
#         <AxesSubplot: xlabel='Fbs', ylabel='Age'>,
#         <AxesSubplot: xlabel='RestECG', ylabel='Age'>,
#         <AxesSubplot: xlabel='MaxHR', ylabel='Age'>,
#         <AxesSubplot: xlabel='ExAng', ylabel='Age'>,
#         <AxesSubplot: xlabel='Oldpeak', ylabel='Age'>,
#         <AxesSubplot: xlabel='Slope', ylabel='Age'>,
#         <AxesSubplot: xlabel='Ca', ylabel='Age'>],
#        [<AxesSubplot: xlabel='Unnamed: 0', ylabel='Sex'>,
#         <AxesSubplot: xlabel='Age', ylabel='Sex'>,
#         <AxesSubplot: xlabel='Sex', ylabel='Sex'>,
#         <AxesSubplot: xlabel='RestBP', ylabel='Sex'>,
#         <AxesSubplot: xlabel='Chol', ylabel='Sex'>,
#         <AxesSubplot: xlabel='Fbs', ylabel='Sex'>,
#         <AxesSubplot: xlabel='RestECG', ylabel='Sex'>,
#         <AxesSubplot: xlabel='MaxHR', ylabel='Sex'>,
#         <AxesSubplot: xlabel='ExAng', ylabel='Sex'>,
#         <AxesSubplot: xlabel='Oldpeak', ylabel='Sex'>,
#         <AxesSubplot: xlabel='Slope', ylabel='Sex'>,
#         <AxesSubplot: xlabel='Ca', ylabel='Sex'>],
#        [<AxesSubplot: xlabel='Unnamed: 0', ylabel='RestBP'>,
#         <AxesSubplot: xlabel='Age', ylabel='RestBP'>,
#         <AxesSubplot: xlabel='Sex', ylabel='RestBP'>,
#         <AxesSubplot: xlabel='RestBP', ylabel='RestBP'>,
#         <AxesSubplot: xlabel='Chol', ylabel='RestBP'>,
#         <AxesSubplot: xlabel='Fbs', ylabel='RestBP'>,
#         <AxesSubplot: xlabel='RestECG', ylabel='RestBP'>,
#         <AxesSubplot: xlabel='MaxHR', ylabel='RestBP'>,
#         <AxesSubplot: xlabel='ExAng', ylabel='RestBP'>,
#         <AxesSubplot: xlabel='Oldpeak', ylabel='RestBP'>,
#         <AxesSubplot: xlabel='Slope', ylabel='RestBP'>,
#         <AxesSubplot: xlabel='Ca', ylabel='RestBP'>],
#        [<AxesSubplot: xlabel='Unnamed: 0', ylabel='Chol'>,
#         <AxesSubplot: xlabel='Age', ylabel='Chol'>,
#         <AxesSubplot: xlabel='Sex', ylabel='Chol'>,
#         <AxesSubplot: xlabel='RestBP', ylabel='Chol'>,
#         <AxesSubplot: xlabel='Chol', ylabel='Chol'>,
#         <AxesSubplot: xlabel='Fbs', ylabel='Chol'>,
#         <AxesSubplot: xlabel='RestECG', ylabel='Chol'>,
#         <AxesSubplot: xlabel='MaxHR', ylabel='Chol'>,
#         <AxesSubplot: xlabel='ExAng', ylabel='Chol'>,
#         <AxesSubplot: xlabel='Oldpeak', ylabel='Chol'>,
#         <AxesSubplot: xlabel='Slope', ylabel='Chol'>,
#         <AxesSubplot: xlabel='Ca', ylabel='Chol'>],
#        [<AxesSubplot: xlabel='Unnamed: 0', ylabel='Fbs'>,
#         <AxesSubplot: xlabel='Age', ylabel='Fbs'>,
#         <AxesSubplot: xlabel='Sex', ylabel='Fbs'>,
#         <AxesSubplot: xlabel='RestBP', ylabel='Fbs'>,
#         <AxesSubplot: xlabel='Chol', ylabel='Fbs'>,
#         <AxesSubplot: xlabel='Fbs', ylabel='Fbs'>,
#         <AxesSubplot: xlabel='RestECG', ylabel='Fbs'>,
#         <AxesSubplot: xlabel='MaxHR', ylabel='Fbs'>,
#         <AxesSubplot: xlabel='ExAng', ylabel='Fbs'>,
#         <AxesSubplot: xlabel='Oldpeak', ylabel='Fbs'>,
#         <AxesSubplot: xlabel='Slope', ylabel='Fbs'>,
#         <AxesSubplot: xlabel='Ca', ylabel='Fbs'>],
#        [<AxesSubplot: xlabel='Unnamed: 0', ylabel='RestECG'>,
#         <AxesSubplot: xlabel='Age', ylabel='RestECG'>,
#         <AxesSubplot: xlabel='Sex', ylabel='RestECG'>,
#         <AxesSubplot: xlabel='RestBP', ylabel='RestECG'>,
#         <AxesSubplot: xlabel='Chol', ylabel='RestECG'>,
#         <AxesSubplot: xlabel='Fbs', ylabel='RestECG'>,
#         <AxesSubplot: xlabel='RestECG', ylabel='RestECG'>,
#         <AxesSubplot: xlabel='MaxHR', ylabel='RestECG'>,
#         <AxesSubplot: xlabel='ExAng', ylabel='RestECG'>,
#         <AxesSubplot: xlabel='Oldpeak', ylabel='RestECG'>,
#         <AxesSubplot: xlabel='Slope', ylabel='RestECG'>,
#         <AxesSubplot: xlabel='Ca', ylabel='RestECG'>],
#        [<AxesSubplot: xlabel='Unnamed: 0', ylabel='MaxHR'>,
#         <AxesSubplot: xlabel='Age', ylabel='MaxHR'>,
#         <AxesSubplot: xlabel='Sex', ylabel='MaxHR'>,
#         <AxesSubplot: xlabel='RestBP', ylabel='MaxHR'>,
#         <AxesSubplot: xlabel='Chol', ylabel='MaxHR'>,
#         <AxesSubplot: xlabel='Fbs', ylabel='MaxHR'>,
#         <AxesSubplot: xlabel='RestECG', ylabel='MaxHR'>,
#         <AxesSubplot: xlabel='MaxHR', ylabel='MaxHR'>,
#         <AxesSubplot: xlabel='ExAng', ylabel='MaxHR'>,
#         <AxesSubplot: xlabel='Oldpeak', ylabel='MaxHR'>,
#         <AxesSubplot: xlabel='Slope', ylabel='MaxHR'>,
#         <AxesSubplot: xlabel='Ca', ylabel='MaxHR'>],
#        [<AxesSubplot: xlabel='Unnamed: 0', ylabel='ExAng'>,
#         <AxesSubplot: xlabel='Age', ylabel='ExAng'>,
#         <AxesSubplot: xlabel='Sex', ylabel='ExAng'>,
#         <AxesSubplot: xlabel='RestBP', ylabel='ExAng'>,
#         <AxesSubplot: xlabel='Chol', ylabel='ExAng'>,
#         <AxesSubplot: xlabel='Fbs', ylabel='ExAng'>,
#         <AxesSubplot: xlabel='RestECG', ylabel='ExAng'>,
#         <AxesSubplot: xlabel='MaxHR', ylabel='ExAng'>,
#         <AxesSubplot: xlabel='ExAng', ylabel='ExAng'>,
#         <AxesSubplot: xlabel='Oldpeak', ylabel='ExAng'>,
#         <AxesSubplot: xlabel='Slope', ylabel='ExAng'>,
#         <AxesSubplot: xlabel='Ca', ylabel='ExAng'>],
#        [<AxesSubplot: xlabel='Unnamed: 0', ylabel='Oldpeak'>,
#         <AxesSubplot: xlabel='Age', ylabel='Oldpeak'>,
#         <AxesSubplot: xlabel='Sex', ylabel='Oldpeak'>,
#         <AxesSubplot: xlabel='RestBP', ylabel='Oldpeak'>,
#         <AxesSubplot: xlabel='Chol', ylabel='Oldpeak'>,
#         <AxesSubplot: xlabel='Fbs', ylabel='Oldpeak'>,
#         <AxesSubplot: xlabel='RestECG', ylabel='Oldpeak'>,
#         <AxesSubplot: xlabel='MaxHR', ylabel='Oldpeak'>,
#         <AxesSubplot: xlabel='ExAng', ylabel='Oldpeak'>,
#         <AxesSubplot: xlabel='Oldpeak', ylabel='Oldpeak'>,
#         <AxesSubplot: xlabel='Slope', ylabel='Oldpeak'>,
#         <AxesSubplot: xlabel='Ca', ylabel='Oldpeak'>],
#        [<AxesSubplot: xlabel='Unnamed: 0', ylabel='Slope'>,
#         <AxesSubplot: xlabel='Age', ylabel='Slope'>,
#         <AxesSubplot: xlabel='Sex', ylabel='Slope'>,
#         <AxesSubplot: xlabel='RestBP', ylabel='Slope'>,
#         <AxesSubplot: xlabel='Chol', ylabel='Slope'>,
#         <AxesSubplot: xlabel='Fbs', ylabel='Slope'>,
#         <AxesSubplot: xlabel='RestECG', ylabel='Slope'>,
#         <AxesSubplot: xlabel='MaxHR', ylabel='Slope'>,
#         <AxesSubplot: xlabel='ExAng', ylabel='Slope'>,
#         <AxesSubplot: xlabel='Oldpeak', ylabel='Slope'>,
#         <AxesSubplot: xlabel='Slope', ylabel='Slope'>,
#         <AxesSubplot: xlabel='Ca', ylabel='Slope'>],
#        [<AxesSubplot: xlabel='Unnamed: 0', ylabel='Ca'>,
#         <AxesSubplot: xlabel='Age', ylabel='Ca'>,
#         <AxesSubplot: xlabel='Sex', ylabel='Ca'>,
#         <AxesSubplot: xlabel='RestBP', ylabel='Ca'>,
#         <AxesSubplot: xlabel='Chol', ylabel='Ca'>,
#         <AxesSubplot: xlabel='Fbs', ylabel='Ca'>,
#         <AxesSubplot: xlabel='RestECG', ylabel='Ca'>,
#         <AxesSubplot: xlabel='MaxHR', ylabel='Ca'>,
#         <AxesSubplot: xlabel='ExAng', ylabel='Ca'>,
#         <AxesSubplot: xlabel='Oldpeak', ylabel='Ca'>,
#         <AxesSubplot: xlabel='Slope', ylabel='Ca'>,
#         <AxesSubplot: xlabel='Ca', ylabel='Ca'>]], dtype=object)

# %%
sns.boxplot(x=data["Age"])
# Out:
# <AxesSubplot: xlabel='Age'>

# %%
sns.boxplot(x=data["Sex"])
# Out:
# <AxesSubplot: xlabel='Sex'>

# %%
sns.boxplot(x=data["RestBP"])
# Out:
# <AxesSubplot: xlabel='RestBP'>

# %%
sns.boxplot(x=data["Chol"])
# Out:
# <AxesSubplot: xlabel='Chol'>

# %%
sns.boxplot(x=data["MaxHR"])
# Out:
# <AxesSubplot: xlabel='MaxHR'>

# %%
sns.violinplot(x=data["Age"])
# Out:
# <AxesSubplot: xlabel='Age'>

# %%
sns.violinplot(x=data["Sex"])
# Out:
# <AxesSubplot: xlabel='Sex'>

# %%
sns.violinplot(x=data["RestBP"])
# Out:
# <AxesSubplot: xlabel='RestBP'>

# %%
sns.violinplot(x=data["Chol"])
# Out:
# <AxesSubplot: xlabel='Chol'>

# %%
sns.violinplot(x=data["MaxHR"])
# Out:
# <AxesSubplot: xlabel='MaxHR'>

# %%
sns.kdeplot(data=data, x=data['Age'])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data=data, x=data['Sex'])
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='Density'>

# %%
sns.kdeplot(data=data, x=data['MaxHR'])
# Out:
# <AxesSubplot: xlabel='MaxHR', ylabel='Density'>

# %%
sns.kdeplot(data=data, x=data['Chol'])
# Out:
# <AxesSubplot: xlabel='Chol', ylabel='Density'>

# %%
sns.kdeplot(data=data, x=data['RestBP'])
# Out:
# <AxesSubplot: xlabel='RestBP', ylabel='Density'>
